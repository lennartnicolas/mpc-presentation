# %% [markdown]
# ## A Correlational Study of Music Engagement and Earliest Musical Memory Vividness and Emotional Intensity
#
# In this study we investigate the relationships between music engagement of adults and earliest musical memories. In particular, we analyzed if there is any correlation between vividness and emotional intensity of these earliest musical memories and music engagement in adult life.
# Our research question can be defined as follows:
# What is the relationship between a person’s engagement with music, and the vividness and emotional intensity of their earliest musical memories?

# %% [markdown]
# ### The Dataset
#
# To obtain data for our research we conducted a survey with several questions relating to memory, vividness as well as demographic information. The results of our analysis of the 59 responses will be presented in this notebook. Before that, we had to preprocess the data from the survey to make it fit for further analysis. The following figure is showing a brief explanation of the filtering.
#
# ![Dataset Extraction!](data/img/mpc_methodology.png)

# %%
# Settings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load Dataset
filepath = 'data/MPC Survey Responses Filtered.xlsx'
df = pd.read_excel(filepath)

# Center plots
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
df
# Out:
#        Gender                Age      MusicTraining  MusicalityRating  \
# 0      Female  Between 21 and 29  more than 9 years                10
# 1        Male  Between 21 and 29        6 - 8 years                 7
# 2        Male  Between 21 and 29        6 - 8 years                 8
# 3   Nonbinary  Between 21 and 29  more than 9 years                10
# 4        Male  Between 30 and 39  more than 9 years                 7
# 5      Female         50 or more        0 - 2 years                 5
# 6      Female        20 or below  more than 9 years                 7
# 7        Male  Between 21 and 29        0 - 2 years                 3
# 8   Nonbinary  Between 21 and 29        0 - 2 years                 5
# 9      Female  Between 21 and 29        3 - 5 years                 7
# 10  Nonbinary  Between 21 and 29        6 - 8 years                 8
# 11       Male  Between 21 and 29        6 - 8 years                 8
# 12  Nonbinary  Between 21 and 29        0 - 2 years                 8
# 13       Male  Between 21 and 29        3 - 5 years                 5
# 14     Female  Between 21 and 29  more than 9 years                 8
# 15     Female  Between 21 and 29        6 - 8 years                 8
# 16     Female        20 or below        6 - 8 years                 6
# 17       Male  Between 21 and 29        0 - 2 years                 4
# 18     Female  Between 21 and 29               None                 5
# 19     Female  Between 21 and 29  more than 9 years                 8
# 20     Female  Between 21 and 29  more than 9 years                 8
# 21     Female  Between 21 and 29        3 - 5 years                 8
# 22  Nonbinary  Between 21 and 29        0 - 2 years                 7
# 23     Female        20 or below               None                 3
# 24     Female  Between 21 and 29        6 - 8 years                 7
# 25       Male  Between 21 and 29        3 - 5 years                 7
# 26  Nonbinary  Between 21 and 29  more than 9 years                 6
# 27       Male  Between 21 and 29        0 - 2 years                 4
# 28       Male  Between 21 and 29        6 - 8 years                 9
# 29     Female  Between 21 and 29  more than 9 years                 8
# 30     Female  Between 21 and 29  more than 9 years                10
# 31     Female  Between 21 and 29        6 - 8 years                 7
# 32     Female  Between 21 and 29  more than 9 years                 8
# 33       Male  Between 21 and 29               None                 4
# 34       Male  Between 21 and 29               None                 4
# 35     Female  Between 21 and 29  more than 9 years                 9
# 36       Male  Between 21 and 29        6 - 8 years                 7
# 37     Female  Between 21 and 29  more than 9 years                 7
# 38       Male  Between 21 and 29  more than 9 years                 6
# 39     Female  Between 21 and 29               None                 5
# 40  Nonbinary  Between 21 and 29        0 - 2 years                 8
# 41     Female  Between 21 and 29  more than 9 years                 7
# 42     Female  Between 21 and 29               None                 4
# 43       Male  Between 21 and 29  more than 9 years                 6
# 44     Female  Between 21 and 29  more than 9 years                 6
# 45     Female  Between 21 and 29        3 - 5 years                 7
# 46     Female  Between 21 and 29        0 - 2 years                 4
# 47     Female  Between 21 and 29  more than 9 years                 7
# 48       Male  Between 21 and 29  more than 9 years                 7
# 49     Female  Between 21 and 29               None                 3
# 50     Female  Between 21 and 29               None                 6
# 51     Female        20 or below  more than 9 years                 9
# 52       Male        20 or below  more than 9 years                10
# 53     Female        20 or below  more than 9 years                 8
# 54       Male  Between 21 and 29  more than 9 years                 8
# 55     Female  Between 30 and 39        3 - 5 years                 6
# 56       Male  Between 21 and 29               None                 4
# 57     Female  Between 21 and 29  more than 9 years                 7
# 58       Male  Between 30 and 39               None                 4
#
#     musEQScore           MQ1  MQ2  MQ3  MQ4  MQ5  RecollectionScore  \
# 0     4.666667   4 - 6 years    5  4.0  3.0    5           5.666667
# 1     3.833333   4 - 6 years    2  4.0  1.0    4           2.000000
# 2     4.833333   4 - 6 years    3  3.0  3.0    3           4.666667
# 3     5.000000   2 - 3 years    4  5.0  3.0    5           4.333333
# 4     4.500000   2 - 3 years    2  3.0  2.0    4           3.666667
# 5     2.666667   2 - 3 years    4  1.0  4.0    5           3.000000
# 6     4.166667   2 - 3 years    3  5.0  2.0    5           2.666667
# 7     3.166667   4 - 6 years    1  1.0  2.0    3           2.333333
# 8     4.000000   2 - 3 years    4  1.0  2.0    5           4.666667
# 9     4.666667     1/2 years    5  5.0  2.0    5           6.000000
# 10    4.500000   2 - 3 years    3  4.0  2.0    5           4.333333
# 11    4.666667   4 - 6 years    5  2.0  1.0    5           5.000000
# 12    4.500000     1/2 years    5  5.0  1.0    4           4.666667
# 13    4.833333   4 - 6 years    3  2.0  2.0    4           1.000000
# 14    4.666667   4 - 6 years    4  4.0  3.0    4           5.000000
# 15    4.333333   4 - 6 years    4  4.0  2.0    4           5.000000
# 16    4.333333   4 - 6 years    5  5.0  4.0    5           3.666667
# 17    2.500000   4 - 6 years    3  2.0  4.0    3           2.000000
# 18    3.333333   4 - 6 years    3  4.0  1.0    5           4.333333
# 19    4.666667   2 - 3 years    3  5.0  2.0    4           5.333333
# 20    4.333333   4 - 6 years    2  2.0  2.0    5           3.666667
# 21    4.333333   2 - 3 years    4  5.0  2.0    5           5.666667
# 22    4.666667   4 - 6 years    3  5.0  2.0    5           5.666667
# 23    2.500000   4 - 6 years    1  3.0  1.0    3           1.333333
# 24    4.666667   2 - 3 years    5  4.0  5.0    5           6.333333
# 25    4.000000   4 - 6 years    5  4.0  3.0    4           3.666667
# 26    4.166667   4 - 6 years    3  4.0  2.0    4           4.000000
# 27    4.666667   4 - 6 years    3  5.0  2.0    5           4.000000
# 28    4.166667   2 - 3 years    4  4.0  4.0    4           5.000000
# 29    4.833333   2 - 3 years    5  4.0  4.0    5           6.333333
# 30    3.000000     1/2 years    3  5.0  3.0    5           3.666667
# 31    3.000000   4 - 6 years    4  4.0  2.0    5           6.333333
# 32    4.500000   4 - 6 years    1  NaN  2.0    5           4.000000
# 33    2.833333   4 - 6 years    2  4.0  NaN    5           5.000000
# 34    2.833333   4 - 6 years    3  4.0  2.0    5           5.666667
# 35    4.666667        1 year    5  5.0  3.0    5           5.333333
# 36    3.500000   4 - 6 years    4  3.0  2.0    5           3.000000
# 37    3.833333   2 - 3 years    3  4.0  3.0    5           5.000000
# 38    4.333333   4 - 6 years    3  3.0  2.0    4           4.000000
# 39    3.000000   4 - 6 years    2  5.0  3.0    5           5.000000
# 40    3.666667   4 - 6 years    5  2.0  4.0    5           4.000000
# 41    4.666667   2 - 3 years    4  4.0  2.0    5           6.000000
# 42    2.500000   2 - 3 years    3  4.0  3.0    4           4.000000
# 43    4.500000   2 - 3 years    3  4.0  2.0    4           4.000000
# 44    3.500000   4 - 6 years    5  5.0  5.0    4           5.333333
# 45    3.833333  7 - 10 years    4  3.0  5.0    4           5.000000
# 46    2.666667   4 - 6 years    2  3.0  3.0    4           3.000000
# 47    4.333333   4 - 6 years    1  1.0  4.0    5           7.000000
# 48    3.833333   2 - 3 years    3  4.0  3.0    5           3.666667
# 49    2.166667   4 - 6 years    2  2.0  1.0    5           1.666667
# 50    3.166667     1/2 years    3  4.0  5.0    5           4.666667
# 51    5.000000       0 years    5  5.0  5.0    5           7.000000
# 52    4.166667   2 - 3 years    2  2.0  2.0    5           3.000000
# 53    4.666667       0 years    4  5.0  5.0    4           6.000000
# 54    3.333333   4 - 6 years    2  2.0  2.0    3           2.666667
# 55    3.000000        1 year    4  3.0  4.0    3           4.000000
# 56    2.833333  7 - 10 years    3  4.0  2.0    5           3.333333
# 57    4.333333   4 - 6 years    1  5.0  1.0    3           6.000000
# 58    3.500000   4 - 6 years    4  2.0  2.0    5           6.333333
#
#     BeliefScore  RehearsalScore  MemoryProvided  \
# 0          6.25             2.5               1
# 1          5.25             2.0               0
# 2          4.25             5.0               0
# 3          3.50             4.5               0
# 4          2.75             4.0               0
# 5          4.50             3.0               1
# 6          4.25             1.5               0
# 7          3.00             1.0               0
# 8          5.75             4.5               1
# 9          6.00             5.0               0
# 10         3.25             5.0               1
# 11         6.00             4.0               1
# 12         2.25             4.0               1
# 13         3.50             2.5               1
# 14         5.25             5.5               1
# 15         4.75             5.5               1
# 16         4.75             5.0               1
# 17         3.25             2.5               1
# 18         2.25             6.5               1
# 19         5.25             5.0               1
# 20         4.25             5.5               1
# 21         7.00             4.5               1
# 22         5.50             6.0               1
# 23         3.00             1.0               0
# 24         6.00             6.5               0
# 25         5.25             4.5               0
# 26         4.75             4.5               0
# 27         4.50             2.0               0
# 28         5.25             6.0               0
# 29         6.50             5.5               1
# 30         3.75             7.0               1
# 31         6.25             4.5               0
# 32         4.25             3.0               1
# 33         3.75             4.5               0
# 34         4.75             6.5               0
# 35         5.75             6.5               1
# 36         4.50             3.5               0
# 37         6.00             5.0               1
# 38         5.00             3.0               0
# 39         7.00             3.5               1
# 40         4.25             6.5               1
# 41         7.00             7.0               1
# 42         5.00             4.0               0
# 43         4.00             2.5               0
# 44         6.25             3.0               1
# 45         5.00             2.0               1
# 46         4.00             3.0               0
# 47         4.00             3.5               0
# 48         5.00             5.0               0
# 49         4.00             1.5               0
# 50         4.75             4.0               0
# 51         7.00             7.0               0
# 52         6.00             3.5               0
# 53         6.00             6.5               0
# 54         4.75             1.0               1
# 55         4.25             5.5               0
# 56         6.00             3.0               0
# 57         5.25             3.5               1
# 58         5.25             5.0               0
#
#                                              Memories
# 0   I was five years old, and I remember very clea...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   My great uncle came for a visit. He sat at the...
# 6                                                 NaN
# 7                                                 NaN
# 8   My first concert - James Taylor at an outdoor ...
# 9                                                 NaN
# 10  Singing a very specific hello song with my mot...
# 11  I remember my father used to sing a tune which...
# 12  My mother is a cellist and every single day sh...
# 13  My Blues Clues Solar System toy that sang abou...
# 14  My dad used to always blast music while he was...
# 15  We held a short dance performance in kindergar...
# 16  My mom used to sing me a Hebrew song to help m...
# 17  Hey Sam, it’s me Arturo Manzo. Cool work with ...
# 18  I always remember my parents cleaning the hous...
# 19  My first musical memory is practicing the cell...
# 20  I loved ballet as a kid and would have my mom ...
# 21  my mother in her rocking chair, singing to me ...
# 22  My mom was really into the clubbing scene in N...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  A Christmas roadtrip to Granada with my parent...
# 30  Se trata de una nana que mi madre solía cantar...
# 31                                                NaN
# 32  I remember watching my sister playing the pian...
# 33                                                NaN
# 34                                                NaN
# 35  My grandma singing me a song called “Chalaneru...
# 36                                                NaN
# 37       La nana que me cantaba mi madre para dormir
# 38                                                NaN
# 39  There was a Disney songs  casette in my home. ...
# 40  Its a memory of my dad singing to me a french ...
# 41  I remember every time I was on my father's car...
# 42                                                NaN
# 43                                                NaN
# 44  Lullaby songs: two that my father created por ...
# 45  I remember listening to Tears In Heaven during...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54  i was in kindergarden and a music teacher intr...
# 55                                                NaN
# 56                                                NaN
# 57     My early music school graduation (8 years old)
# 58                                                NaN

# %% [markdown]
# ### Demographics
#
# In this section we introduce some demographic information of the survey takers. We aimed to reach a diverse population of people with different perspectives towards music to get a balanced representation and explore possible correlations.

# %%
df.groupby(['Gender', 'Age']).size().plot(kind='pie', 
                                          figsize=(10,10), 
                                          ylabel=' ', 
                                          autopct='%1.1f%%', 
                                          title='An Overview of the survey takers',
                                          colormap='PuBuGn')

plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2,figsize=(10,6))

df.MusicTraining.value_counts().plot(
                                     kind='pie',
                                     autopct='%1.1f%%',
                                     colormap='YlGn',
                                     ylabel=' ',
                                     ax=ax[0],
                                     title='Music Training')

df.MusicalityRating.value_counts().sort_index().plot(
                                     kind='pie',
                                     ylabel=' ',
                                     colormap='BuPu',
                                     ax=ax[1],
                                     autopct='%1.1f%%',
                                     title='Musicality')

plt.tight_layout()

# %% [markdown]
# ### Music Engagement
#
# We now present the scores outcome of the musEQ questionnaire. The musEQ paper can be found [here](DOI:10.1080/13607863.2015.1021750). The original questionnaire contains 35 items for 6 categories which we shrinked down to 8 items for 6 categories to make it fit for the scope of our work. We then used the mean value for each category and obtained the musEQ score which is presented in the following figures.

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))

ax[0].plot(df.MusicalityRating, df.musEQScore, 'o', fillstyle='none', color='goldenrod')
df.groupby('MusicalityRating')['musEQScore'].median().plot(xlabel='Musicality Rating',
                                                         ylabel='musEQ Score',
                                                         label='Median Scores',
                                                         color='lightsalmon',
                                                         ax=ax[0]).legend(loc='upper left')

df.groupby('MusicalityRating')['musEQScore'].mean().plot(xlabel='Musicality Rating',
                                                         ylabel='musEQ Score',
                                                         label='Mean Scores',
                                                         color='gold',
                                                         title='Median and Mean Scores',
                                                         ax=ax[0]).legend(loc='upper left')

# Fitting a linear function to show relationship
X = np.transpose(np.array([3,4,5,6,7,8,9,10]).reshape(1,-1))
y = np.array(df.groupby('MusicalityRating')['musEQScore'].median())
lr = LinearRegression().fit(X,y)

ax[1].scatter(X, y, marker='o', facecolors='none', color='lightsalmon', label='Median Scores')
ax[1].plot(X, lr.predict(X) , color='crimson', label='Prediction function: {coef:.3f} * x + {intercept:.3f}'.format(coef=lr.coef_[0], intercept=lr.intercept_))
ax[1].set_xlabel('Musicality Rating')
ax[1].legend()
ax[1].set_title('Linear Regression for Median Scores')

plt.tight_layout()
# Out:
# [0.31051587]
# 1.804563492063492
